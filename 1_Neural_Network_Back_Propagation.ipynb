# %% [markdown]
# <a href="https://colab.research.google.com/github/YashshwiniThakkar/YashshwiniThakkar/blob/main/1_Neural_Network_Back_Propagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
# !pip install keras

# %%
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes.data.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# create model
model = Sequential()
model.add(Dense(8, input_dim=8,  activation='relu')) #1st layer
model.add(Dense(8,  activation='relu')) #2nd layer
model.add(Dense(1, activation='sigmoid')) #3rd layer or op layer

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
history = model.fit(X, Y, validation_split=0.33, epochs=250, batch_size=10)
# Out:
# Epoch 1/250
# 52/52 [==============================] - 1s 5ms/step - loss: 9.4077 - accuracy: 0.6284 - val_loss: 4.6194 - val_accuracy: 0.6181
# Epoch 2/250
# 52/52 [==============================] - 0s 2ms/step - loss: 2.8443 - accuracy: 0.4708 - val_loss: 1.6508 - val_accuracy: 0.4449
# Epoch 3/250
# 52/52 [==============================] - 0s 2ms/step - loss: 1.2628 - accuracy: 0.5428 - val_loss: 1.3869 - val_accuracy: 0.5276
# Epoch 4/250
# 52/52 [==============================] - 0s 2ms/step - loss: 1.1270 - accuracy: 0.6148 - val_loss: 1.2666 - val_accuracy: 0.5433
# Epoch 5/250
# 52/52 [==============================] - 0s 3ms/step - loss: 1.0438 - accuracy: 0.5992 - val_loss: 1.1266 - val_accuracy: 0.5551
# Epoch 6/250
# 52/52 [==============================] - 0s 3ms/step - loss: 0.9861 - accuracy: 0.5914 - val_loss: 1.0532 - val_accuracy: 0.5906
# Epoch 7/250
# ...

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5151 - accuracy: 0.7383
# accuracy: 73.83%
